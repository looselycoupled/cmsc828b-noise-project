# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
y = [22.85, 14.50, 10.29, 4.62, 3.87, 3.84]
x = ['0%','5%','10%','20%','50%','100%']

fig, ax = plt.subplots()
barlist = ax.bar(x,y)
ax.set_ylabel("BLEU score")
ax.set_xlabel("percentage of noise")
ax.set_title("BLEU vs Percentage of Noise")

plt.show(0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/allen/.pyenv/versions/noise-alt/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Passing arguments to show(), other than passing 'block' by keyword, is deprecated 3.1, and support for it will be removed in 3.3.
#   # Remove the CWD from sys.path while we load stuff.

# %%
y = [22.85, 14.50, 10.29, 4.62, 3.87, 3.84]
huda = [27.2, 17.6, 11.2, 5.6, 3.2, 3.2]
labels = ['0%','5%','10%','20%','50%','100%']

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
barlist = ax.bar(x - (width/2),y, width=width, label="transformer")
barlist = ax.bar(x + (width/2),huda, color="lawngreen", width=width, label="rnn")

ax.set_xticks(x)
ax.set_xticklabels(labels)

ax.set_ylabel("BLEU score")
ax.set_xlabel("percentage of noise")
ax.set_title("BLEU vs Percentage of Noise")

plt.legend()
plt.show(0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/allen/.pyenv/versions/noise-alt/lib/python3.7/site-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Passing arguments to show(), other than passing 'block' by keyword, is deprecated 3.1, and support for it will be removed in 3.3.

# %%
y = [22.85, 21.55, 20.85, 21.51, 19.35, 14.50, 10.29, 4.62, 3.87, 3.84]
x = ['0%','1%','2%','3%','4%','5%','10%','20%','50%','100%']

fig, ax = plt.subplots()
barlist = ax.bar(x,y)
ax.set_ylabel("BLEU score")
ax.set_xlabel("percentage of noise")
ax.set_title("BLEU vs Percentage of Noise (All Experiments)")

plt.show(0)

barlist[1].set_color('lawngreen')
barlist[2].set_color('lawngreen')
barlist[3].set_color('lawngreen')
barlist[4].set_color('lawngreen')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/allen/.pyenv/versions/noise-alt/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Passing arguments to show(), other than passing 'block' by keyword, is deprecated 3.1, and support for it will be removed in 3.3.
#   # Remove the CWD from sys.path while we load stuff.

# %%
y = [22.85, 21.55, 20.85, 21.51, 19.35, 14.50, 10.29, 4.62, 3.87, 3.84]
x = ['0%','1%','2%','3%','4%','5%','10%','20%','50%','100%']

fig, ax = plt.subplots()
barlist = ax.plot(x,y)
ax.set_ylabel("BLEU score")
ax.set_xlabel("percentage of noise")
ax.set_title("BLEU vs Percentage of Noise (All Experiments)")

plt.show(0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/allen/.pyenv/versions/noise-alt/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Passing arguments to show(), other than passing 'block' by keyword, is deprecated 3.1, and support for it will be removed in 3.3.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Source Copy Percentage Chart
#
# Calculated counts for source copied.
#
# ```
# translation.1.en
# total lines: 3004
# total copies: 1
# total similar copies: 43
# translation.2.en
# total lines: 3004
# total copies: 12
# total similar copies: 69
# translation.3.en
# total lines: 3004
# total copies: 33
# total similar copies: 117
# translation.4.en
# total lines: 3004
# total copies: 129
# total similar copies: 244
# translation.5.en
# total lines: 3004
# total copies: 611
# total similar copies: 1024
# translation.10.en
# total lines: 3004
# total copies: 1322
# total similar copies: 1777
# translation.20.en
# total lines: 3004
# total copies: 1678
# total similar copies: 2720
# translation.50.en
# total lines: 3004
# total copies: 2544
# total similar copies: 2940
# translation.100.en
# total lines: 3004
# total copies: 1897
# total similar copies: 2952
# ```

# %%
total = 3004

total = 3004

copies = np.array([1, 12, 33, 129, 611, 1322, 1678, 2544, 1897]) / total 
copies = copies * 100
copies = copies.astype(int).tolist()

similar_copies = np.array([43, 69, 117, 244, 1024, 1777, 2720, 2940, 2952]) / total
similar_copies = similar_copies * 100
similar_copies = (similar_copies.astype(int) - copies).tolist()


labels = ['1%','2%','3%','4%','5%','10%','20%','50%','100%']

fig, ax = plt.subplots()
width = 0.35 

ax.bar(labels, copies, width, label='Copied Sentences')
ax.bar(labels, similar_copies, width, bottom=copies, label='Similar Sentences', color="lightsteelblue")

ax.set_ylabel('percentage of sentences')
ax.set_xlabel('amount of noise')
ax.set_title('Untranslated Target Copying')
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
